# %% [markdown]
# # Exploratory Data Analysis

# %%
# import the libraries
# %matplotlib inline

import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

# apply style to all the charts
sns.set_style('whitegrid')

# convert scientific notation to decimals
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# ## Load the clean dataset

# %%
# Load the data
df = pd.read_csv('../../Data/Processed/black_friday_processed.csv')
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# ...

# %% [markdown]
# ## Data Perspective

# %% [markdown]
# ### One Variable (numeric)

# %%
# Analize purchase distribuction

# Histogram
print(df['Purchase'].describe().round())
plt.hist(df['Purchase'], bins=100)
plt.show()
# Box plot
plt.boxplot(df['Purchase'])
plt.xticks([1], ['Purchase'], rotation='horizontal')
plt.show()
# Out:
# count   537577.00
# mean      9334.00
# std       4981.00
# min        185.00
# 25%       5866.00
# 50%       8062.00
# 75%      12073.00
# max      23961.00
# Name: Purchase, dtype: float64

# %% [markdown]
# As we can see through the histogram and bosplot charts, the majority of transactions in the dataset results in purchase amounts between 5000 and 15000 dolars, with 75% of the transactions resulting in 12000 purchase amount. The maximum purchase amount is less than 25000 dolars.

# %% [markdown]
# ## One Variable (categorical)

# %%
# Analize transactions distribution
print(df['Gender'].value_counts())

# Bar Chart
plt.figure(figsize=(12,6))
plt.title('# Transactions by Gender')
plt.xlabel('Gender')
plt.ylabel('# Transactions')

labels = df['Gender'].value_counts().index
values = df['Gender'].value_counts().values

y_pos = range(len(labels))
plt.bar(y_pos, values, align='center', alpha=0.5)
plt.xticks(y_pos, labels)
plt.show()
# Out:
# M    405380
# F    132197
# Name: Gender, dtype: int64

# %% [markdown]
# As we can see in this bar chart, more than 75% of the transactions were made by men, while women were responsible for less 25% of them.

# %%
# Analize transactions distribution
print(df['Age'].value_counts())

# Bar Chart
plt.figure(figsize=(12,6))
plt.title('# Transactions by Age')
plt.xlabel('Age')
plt.ylabel('# Transactions')

labels = df['Age'].value_counts().index
values = df['Age'].value_counts().values

y_pos = range(len(labels))
plt.bar(y_pos, values, align='center', alpha=0.5)
plt.xticks(y_pos, labels)
plt.show()
# Out:
# 26-35    214690
# 36-45    107499
# 18-25     97634
# 46-50     44526
# 51-55     37618
# 55+       20903
# 0-17      14707
# Name: Age, dtype: int64

# %% [markdown]
# In this case, the bar chart shows that the costumers between 26 and 35 years old are the main buyers for the retail store (40% of the transactions), while the teenagers until 17 years old are the less expressive ones (3% of the transactions).

# %%
# Analize transactions distribution
print(df['Occupation'].value_counts())

# Bar Chart
plt.figure(figsize=(12,6))
plt.title('# Transactions by Occupation')
plt.xlabel('Occupation')
plt.ylabel('# Transactions')

labels = df['Occupation'].value_counts().index
values = df['Occupation'].value_counts().values

y_pos = range(len(labels))
plt.bar(y_pos, values, align='center', alpha=0.5)
plt.xticks(y_pos, labels)
plt.show()
# Out:
# 4     70862
# 0     68120
# 7     57806
# 1     45971
# 17    39090
# 20    32910
# 12    30423
# 14    26712
# 2     25845
# 16    24790
# 6     19822
# 3     17366
# 10    12623
# 5     11985
# 15    11812
# 11    11338
# 19     8352
# 13     7548
# 18     6525
# 9      6153
# 8      1524
# Name: Occupation, dtype: int64

# %% [markdown]
# This bar chart shows that customers working in professions 4, 0, 7, 1 and 17 are the main clients for such retail store.

# %%
# Analize transactions distribution
print(df['City_Category'].value_counts())

# Bar Chart
plt.figure(figsize=(12,6))
plt.title('# Transactions by City')
plt.xlabel('City_Category')
plt.ylabel('# Transactions')

labels = df['City_Category'].value_counts().index
values = df['City_Category'].value_counts().values

y_pos = range(len(labels))
plt.bar(y_pos, values, align='center', alpha=0.5)
plt.xticks(y_pos, labels)
plt.show()
# Out:
# B    226493
# C    166446
# A    144638
# Name: City_Category, dtype: int64

# %% [markdown]
# This bar chart shows that the city B concentrates the majority of transactions for the retail store.

# %%
# Analize transactions distribution
print(df['Marital_Status'].value_counts())

# Bar Chart
plt.figure(figsize=(12,6))
plt.title('# Transactions by Marital Status')
plt.xlabel('Marital_Status')
plt.ylabel('# Transactions')

labels = df['Marital_Status'].value_counts().index
values = df['Marital_Status'].value_counts().values

y_pos = range(len(labels))
plt.bar(y_pos, values, align='center', alpha=0.5)
plt.xticks(y_pos, labels)
plt.show()
# Out:
# 0    317817
# 1    219760
# Name: Marital_Status, dtype: int64

# %% [markdown]
# This bar chart shows that the city B concentrates the majority of transactions for the retail store.

# %%
# Analize transactions distribution
print(df['Product_Category_1'].value_counts())

# Bar Chart
plt.figure(figsize=(12,6))
plt.title('# Transactions by Product_Category_1')
plt.xlabel('Product_Category_1')
plt.ylabel('# Transactions')

labels = df['Product_Category_1'].value_counts().index
values = df['Product_Category_1'].value_counts().values

y_pos = range(len(labels))
plt.bar(y_pos, values, align='center', alpha=0.5)
plt.xticks(y_pos, labels)
plt.show()
# Out:
# 5     148592
# 1     138353
# 8     112132
# 11     23960
# 2      23499
# 6      20164
# 3      19849
# 4      11567
# 16      9697
# 15      6203
# 13      5440
# 10      5032
# 12      3875
# 7       3668
# 18      3075
# 14      1500
# 17       567
# 9        404
# Name: Product_Category_1, dtype: int64

# %%
# Analize transactions distribution
print(df['Product_Category_2'].value_counts())

# Bar Chart
plt.figure(figsize=(12,6))
plt.title('# Transactions by Product_Category_2')
plt.xlabel('Product_Category_2')
plt.ylabel('# Transactions')

labels = df['Product_Category_2'].value_counts().index
values = df['Product_Category_2'].value_counts().values

y_pos = range(len(labels))
plt.bar(y_pos, values, align='center', alpha=0.5)
plt.xticks(y_pos, labels)
plt.show()
# Out:
# 0     166986
# 8      63058
# 14     54158
# 2      48481
# 16     42602
# 15     37317
# 5      25874
# 4      25225
# 6      16251
# 11     13945
# 17     13130
# 13     10369
# 9       5591
# 12      5419
# 10      2991
# 3       2835
# 18      2730
# 7        615
# Name: Product_Category_2, dtype: int64

# %%
# Analize transactions distribution
print(df['Product_Category_3'].value_counts())

# Bar Chart
plt.figure(figsize=(12,6))
plt.title('# Transactions by Product_Category_3')
plt.xlabel('Product_Category_3')
plt.ylabel('# Transactions')

labels = df['Product_Category_3'].value_counts().index
values = df['Product_Category_3'].value_counts().values

y_pos = range(len(labels))
plt.bar(y_pos, values, align='center', alpha=0.5)
plt.xticks(y_pos, labels)
plt.show()
# Out:
# 0     373299
# 16     32148
# 15     27611
# 14     18121
# 17     16449
# 5      16380
# 8      12384
# 9      11414
# 12      9094
# 13      5385
# 6       4818
# 18      4563
# 4       1840
# 11      1773
# 10      1698
# 3        600
# Name: Product_Category_3, dtype: int64

# %% [markdown]
# When we initially observed the dataset by itself, we could saw that all the transactions were made with products from product category 1 and certain combination of it and the other categories. Maybe there are some hierarchy between them.

# %% [markdown]
# ## Multiple variables (Numeric x Numeric)

# %%
# Correlation
df.corr()
# Out:
#                     User_ID  Occupation  Marital_Status  Product_Category_1  \
# User_ID                1.00       -0.02            0.02                0.00
# Occupation            -0.02        1.00            0.02               -0.01
# Marital_Status         0.02        0.02            1.00                0.02
# Product_Category_1     0.00       -0.01            0.02                1.00
# Product_Category_2     0.00        0.01            0.00               -0.04
# Product_Category_3     0.00        0.01           -0.00               -0.39
# Purchase               0.01        0.02            0.00               -0.31
#
#                     Product_Category_2  Product_Category_3  Purchase
# User_ID                           0.00                0.00      0.01
# Occupation                        0.01                0.01      0.02
# Marital_Status                    0.00               -0.00      0.00
# Product_Category_1               -0.04               -0.39     -0.31
# ...

# %%
# heatmap
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=1, square=True)
plt.show()

# %%
# Correlation between Product of Category 1 x Purchase
print('Correlation:', df[['Product_Category_1', 'Purchase']].corr())
# Correlation between Product of Category 2 x Purchase
print('Correlation:', df[['Product_Category_2', 'Purchase']].corr())
# Correlation between Product of Category 3 x Purchase 
print('Correlation:', df[['Product_Category_3', 'Purchase']].corr())
# Correlation between Product of Product_Category_1 x Product_Category_2 
print('Correlation:', df[['Product_Category_1', 'Product_Category_2']].corr())
# Correlation between Product of Product_Category_1 x Product_Category_3 
print('Correlation:', df[['Product_Category_1', 'Product_Category_3']].corr())
# Correlation between Product of Product_Category_2 x Product_Category_3 
print('Correlation:', df[['Product_Category_2', 'Product_Category_3']].corr())
# Out:
# Correlation:                     Product_Category_1  Purchase
# Product_Category_1                1.00     -0.31
# Purchase                         -0.31      1.00
# Correlation:                     Product_Category_2  Purchase
# Product_Category_2                1.00      0.04
# Purchase                          0.04      1.00
# Correlation:                     Product_Category_3  Purchase
# Product_Category_3                1.00      0.28
# Purchase                          0.28      1.00
# Correlation:                     Product_Category_1  Product_Category_2
# Product_Category_1                1.00               -0.04
# Product_Category_2               -0.04                1.00
# Correlation:                     Product_Category_1  Product_Category_3
# Product_Category_1                1.00               -0.39
# Product_Category_3               -0.39                1.00
# Correlation:                     Product_Category_2  Product_Category_3
# ...

# %% [markdown]
# Regarding correlations between the dataset numerical variables, we can see that the variables do not have much correlation. But the most correlatad ones apparenty are the product categories 1, 2 and 3.

# %% [markdown]
# ## Multiple variables (Categorical x Numeric)

# %%
# Box plot to show the distribution between Gender x Purchase amount
values = []
labels = []
for bdr in sorted(df['Gender'].unique()):
    labels.append(bdr)
    values.append(list(df[df['Gender']==bdr]['Purchase'].values))

plt.boxplot(values)
plt.xticks(range(1,len(labels)+1), labels, rotation='horizontal')
plt.show()

# %%
# Box plot to show the distribution between Age x Purchase amount
values = []
labels = []
for bdr in sorted(df['Age'].unique()):
    labels.append(bdr)
    values.append(list(df[df['Age']==bdr]['Purchase'].values))

plt.boxplot(values)
plt.xticks(range(1,len(labels)+1), labels, rotation='horizontal')
plt.show()

# %%
# Box plot to show the distribution between Occupation x Purchase amount
values = []
labels = []
for bdr in sorted(df['Occupation'].unique()):
    labels.append(bdr)
    values.append(list(df[df['Occupation']==bdr]['Purchase'].values))

plt.boxplot(values)
plt.xticks(range(1,len(labels)+1), labels, rotation='horizontal')
plt.show()

# %%
# Box plot to show the distribution between City_Category x Purchase amount
values = []
labels = []
for bdr in sorted(df['City_Category'].unique()):
    labels.append(bdr)
    values.append(list(df[df['City_Category']==bdr]['Purchase'].values))

plt.boxplot(values)
plt.xticks(range(1,len(labels)+1), labels, rotation='horizontal')
plt.show()

# %%
# Box plot to show the distribution between Stay_In_Current_City_Years x Purchase amount
values = []
labels = []
for bdr in sorted(df['Stay_In_Current_City_Years'].unique()):
    labels.append(bdr)
    values.append(list(df[df['Stay_In_Current_City_Years']==bdr]['Purchase'].values))

plt.boxplot(values)
plt.xticks(range(1,len(labels)+1), labels, rotation='horizontal')
plt.show()

# %%
# Box plot to show the distribution between Marital_Status x Purchase amount
values = []
labels = []
for bdr in sorted(df['Marital_Status'].unique()):
    labels.append(bdr)
    values.append(list(df[df['Marital_Status']==bdr]['Purchase'].values))

plt.boxplot(values)
plt.xticks(range(1,len(labels)+1), labels, rotation='horizontal')
plt.show()

# %%
# Box plot to show the distribution between Product_Category_1 x Purchase amount
values = []
labels = []
for bdr in sorted(df['Product_Category_1'].unique()):
    labels.append(bdr)
    values.append(list(df[df['Product_Category_1']==bdr]['Purchase'].values))

plt.boxplot(values)
plt.xticks(range(1,len(labels)+1), labels, rotation='horizontal')
plt.show()

# %%
# Box plot to show the distribution between Product_Category_2 x Purchase amount
values = []
labels = []
for bdr in sorted(df['Product_Category_2'].unique()):
    labels.append(bdr)
    values.append(list(df[df['Product_Category_2']==bdr]['Purchase'].values))

plt.boxplot(values)
plt.xticks(range(1,len(labels)+1), labels, rotation='horizontal')
plt.show()

# %%
# Box plot to show the distribution between Product_Category_3 x Purchase amount
values = []
labels = []
for bdr in sorted(df['Product_Category_3'].unique()):
    labels.append(bdr)
    values.append(list(df[df['Product_Category_3']==bdr]['Purchase'].values))

plt.boxplot(values)
plt.xticks(range(1,len(labels)+1), labels, rotation='horizontal')
plt.show()

# %% [markdown]
# ## Business Perspective
# "An approximate answer to the right question is worth a great deal more than a precise answer to the wrong question." John Tukey

# %%
# Cat plot to show the distribution between Occupation x Purchase x City
sns.catplot(x = "Occupation",
            y = "Purchase",
            hue = "City_Category",
            hue_order = ["A", "B", "C"],
            aspect = 3,
            kind = "bar",
            data = df)
# Out:
# /home/coastrock/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# This figure accounts for the occupation of our customers across different cities in terms of purchase. Let's first address the spike for Occupation 8 in City A, it showed in the earlier countplot that occupation 8 made up only of a tiny number of purchases, the vertical std bar helps explain this spike probably by a few large transactions. However, we can see that apart from the occupation 8, the graph shows that purchases are highest in City C regardless of occupations. We can therefore make assumptions about the purchasing power from customers in City C.

# %%
# Catplot for Age x Purchase considering the Gender and the City Category
sns.catplot(x = 'Age',
           y = 'Purchase',
           hue = 'Gender',
           col = 'City_Category',
           order = ['0-17', '18-25','26-35', '36-45','46-50', '51-55','55+'],
           hue_order = ['M', 'F'],   
           data = df)

# %% [markdown]
# The above figure shows us the distribution of purchase amounts for respective age group across the cities A, B and C.  Note that in general men in the 26-35 age group are our largest in number and in amount as our highest spending group across all three cities. Women, on the other hand, occurs to peak in number and purchase amount within the 46-50 age group except in City A where the majority of purchase were clearly made by the 0-17 age group.
#
# Based on the above summary, we can advise the store manager to gear their sales effort on the said gender specific age groups on next black friday. The type of products to be chosen will depend on the store past experiences dealing with the respective age group with products that are known to be popular for specific gender.

# %%
# Catplot for Age x Purchase considering the Gender and the Marital Status

sns.catplot(x = 'Age',
           y = 'Purchase',
           hue = 'Gender',
           col = 'Marital_Status',
           order = ['0-17', '18-25','26-35', '36-45','46-50', '51-55','55+'],
           hue_order = ['M', 'F'],   
           data = df)

# %% [markdown]
# To look again at the initial question we asked ourselves about the dataset: whether young single male as the driving force on Black Friday. On one hand, we know from the dataset that the majority of black friday customers are male, in fact, about 3 times more. On the other hand, we will include other factors (Marital status and high purchase amount) to further test our hypothesis. As we deem profitability in terms of sales/purchase amount, we will focus our analysis around the purchase mean of 20000 as higher the amount would typically imply bigger ticket items. As for the age group, we will look at the combined age group from 18-35. We can confirm that further in our later analyses, but the blue color appears to dominate this area.
#
# Note: The legal marrying age at 18 explains the missing column for the 0-17 age group on the second graph
